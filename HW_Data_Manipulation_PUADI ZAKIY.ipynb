# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('1698635826265-telco_customer_churn.csv')
pd.set_option("display.max_columns",None)

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
data = df.copy()
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %% [markdown]
# ### Welcome to Homework. Please answer the questions below!

# %% [markdown]
# Score : Maximal 50.
# Per Soal bobotnya 10

# %% [markdown]
# 1. Buanglah baris dengan `tenure` samadengan 0 (jadi, data yang akan kita analisa di PR ini adalah baris-baris dengan `tenure` TIDAK samadengan 0). Ada berapa baris yang sekarang tersedia di data kita?
#
# 2. Bagi customer yang ***TIDAK MEMILIKI PARTNER*** dan ***TIDAK MEMILIKI DEPENDENTS***, berapa ***rata-rata*** dari `tenure` mereka?
#
# 3. Bagi customer yang ***MEMILIKI PARTNER*** dan ***TIDAK MEMILIKI DEPENDENTS***, berapa maksimal `MonthlyCharges` yang tercata?
#
# 4. Berapa banyak customer yang ***TIDAK MEMILIKI PARTNER*** namun ***MEMILIKI DEPENDENTS***?
#
# 5. Berapa rata-rata ***TOTAL CHARGES*** dari customer ***NON-SENIOR CITIZEN*** (Senior Citizen = 0) yang memiliki ***PHONE SERVICE*** dan memiliki ***INTERNET SERVICE FIBER OPTIC***?

# %% [markdown]
# #### Silakan menuliskan kode untuk menjawab 5 pertanyaan di atas...

# %%
data.shape
# Out:
# (7043, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data_hapus = data.loc[data['tenure'] != 0 ]
print(data_hapus)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
data_hapus.shape
# Out:
# (7032, 21)

# %%
kondisi = data[(data['Partner'] == 'No') & (data['Dependents'] == 'No')]

kondisi['tenure'].mean()
# Out:
# 23.303353658536587

# %%
kondisi2 = data[(data['Partner'] == 'Yes') & (data['Dependents'] == 'No')]

kondisi2['MonthlyCharges'].max()
# Out:
# 118.6

# %%
kondisi2.sort_values(by='MonthlyCharges', ascending=False)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3894  5989-AXPUC  Female              0     Yes         No      68
# 4610  2889-FPWRM    Male              0     Yes         No      72
# 4875  2302-ANTDP  Female              1     Yes         No      48
# 2368  6650-BWFRT  Female              0     Yes         No      72
# 5347  9788-HNGUT    Male              0     Yes         No      72
# ...          ...     ...            ...     ...        ...     ...
# 4927  4774-HHGGS    Male              0     Yes         No      30
# 4304  9732-OUYRN  Female              0     Yes         No      49
# 6178  3719-TDVQB  Female              1     Yes         No      54
# 6925  6508-NJYRO    Male              0     Yes         No      15
# 1529  9764-REAFF  Female              0     Yes         No      59
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  \
# 3894          Yes           Yes     Fiber optic                  Yes
# ...

# %%
kondisi3 = data[(data['Partner'] == 'No') & (data['Dependents'] == 'Yes')]
kondisi3.shape
# Out:
# (361, 21)

# %%
kondisi3['customerID'].nunique()
# Out:
# 361

# %%
data = data[data["TotalCharges"]!=" "]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
data['TotalCharges'] = data['TotalCharges'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
kondisi4 = data[(data['SeniorCitizen'] == 0) 
                & (data['PhoneService'] == 'Yes') 
                & (data['InternetService'] == 'Fiber optic')]

kondisi4['TotalCharges'].mean()
# Out:
# 3226.4927373068435

# %% [markdown]
# ### Silakan menjawab di bawah ini:

# %% [markdown]
# #### Soal 1:
# Buanglah baris dengan tenure samadengan 0 (jadi, data yang akan kita analisa di PR ini adalah baris-baris dengan tenure TIDAK samadengan 0). Ada berapa baris yang sekarang tersedia di data kita?
#
# #### Jawaban: 7032 (langsung edit di sini aja)

# %% [markdown]
# #### Soal 2:
# Bagi customer yang TIDAK MEMILIKI PARTNER dan TIDAK MEMILIKI DEPENDENTS, berapa rata-rata dari tenure mereka?
#
# #### Jawaban: 23.30

# %% [markdown]
# #### Soal 3:
# Bagi customer yang MEMILIKI PARTNER dan TIDAK MEMILIKI DEPENDENTS, berapa maksimal MonthlyCharges yang tercata?
#
# #### Jawaban: 118.6

# %% [markdown]
# #### Soal 4:
# Berapa banyak customer yang TIDAK MEMILIKI PARTNER namun MEMILIKI DEPENDENTS?
#
# #### Jawaban: 361

# %% [markdown]
# #### Soal 5:
# Berapa rata-rata TOTAL CHARGES dari customer NON-SENIOR CITIZEN (Senior Citizen = 0) yang memiliki PHONE SERVICE dan memiliki INTERNET SERVICE FIBER OPTIC?
#
# #### Jawaban: 3226.49

# %% [markdown]
# # Deep Data Manipulation

# %% [markdown]
# Lakukan analisa dengan menggunakan teknik teknik data manipulation yang telah dipelajari sebanyak 2 analisa. kemudian berikan intrepetasi dan alasan anda melakukan analisa tersebut. <br>
#
# Misalnya : <br>
# Melakukan filter monthly charges diatas 500 kemudian saya akan mengalisa percentase churn berdasrkan kelompok A. Hasil temuan, ternyata kelompok tersebut memiliki percent churn sebesar %. <br>
#
# Bobot maksimal 50 <br>
# semakian baik analisa dan intrepetasi disertai alasan yang jelas akan mendapatkan score maximal

# %% [markdown]
# # Bagaimana pengaruh jumlah total charges pada
# * kelompok A(tidak memiliki tanggungan dan tidak memiliki partner),
# * kelompok B (memiliki tanggungan dan tidak memiliki partner),
# * kelompok C (memiliki tanggungan dan memiliki partner) dan
# * kelompok D(tidak memiliki tanggungan dan memiliki partner)?

# %%
kel_a = data[(data['Dependents'] == 'No') & (data['Partner'] == 'No')]
kel_b = data[(data['Dependents'] == 'Yes') & (data['Partner'] == 'No')]
kel_c = data[(data['Dependents'] == 'Yes') & (data['Partner'] == 'Yes')]
kel_d = data[(data['Dependents'] == 'No') & (data['Partner'] == 'Yes')]

# %%
kel_a
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# ...          ...     ...            ...     ...        ...     ...
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 1             Yes                No             DSL                  Yes
# ...

# %%
kel_a['TotalCharges'].sum()
# Out:
# 5283104.0

# %%
kel_a['customerID'].nunique()
# Out:
# 3280

# %%
kel_b
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6     1452-KIOVK    Male              0      No        Yes      22
# 9     6388-TABGU    Male              0      No        Yes      62
# 17    9959-WOFKT    Male              0      No        Yes      71
# 29    8773-HHUOZ  Female              0      No        Yes      17
# 74    5630-AHZIL  Female              0      No        Yes       3
# ...          ...     ...            ...     ...        ...     ...
# 6946  9013-AQORL  Female              0      No        Yes      48
# 6966  6598-KELSS    Male              0      No        Yes      50
# 6979  5351-QESIO    Male              0      No        Yes       1
# 6984  6447-GORXK    Male              0      No        Yes      31
# 6995  7164-BPTUT    Male              0      No        Yes      57
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 6             Yes               Yes     Fiber optic             No
# ...

# %%
kel_b['TotalCharges'].sum()
# Out:
# 484567.0

# %%
kel_b['customerID'].nunique()
# Out:
# 359

# %%
kel_c
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 18    4190-MFLUW  Female              0     Yes        Yes      10
# 24    6322-HRPFA    Male              0     Yes        Yes      49
# 26    6467-CHFZW    Male              0     Yes        Yes      47
# ...          ...     ...            ...     ...        ...     ...
# 7018  1122-JWTJW    Male              0     Yes        Yes       1
# 7020  9837-FWLCH    Male              0     Yes        Yes      12
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 10            Yes                No             DSL                  Yes
# ...

# %%
kel_c['TotalCharges'].sum()
# Out:
# 4779631.95

# %%
kel_c['customerID'].nunique()
# Out:
# 1740

# %%
kel_d
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 8     7892-POOKP  Female              0     Yes         No      28
# 12    8091-TTVAX    Male              0     Yes         No      58
# 21    1680-VDCWW    Male              0     Yes         No      12
# 23    3638-WEABW  Female              0     Yes         No      58
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7024  7398-LXGYX    Male              0     Yes         No      44
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7031  3605-JISKB    Male              1     Yes         No      55
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 0              No  No phone service             DSL                   No
# ...

# %%
kel_d['TotalCharges'].sum()
# Out:
# 5508865.75

# %% [markdown]
# #### kel_a = 5,283,104 (3280)
# #### kel_b = 484,567 (359)
# #### kel_c = 4,779,631.95 (1740)
# #### kel_d = 5,508,865.75 (1653)
#
# * --> jumlah total charges paling dipengaruhi oleh dependents, ini terbukti pada data jumlah total charges kelompok B yang mana mereka tidak memiliki partner akan tetapi memiliki tanggungan, sehingga income mereka dialokasikan untuk tanggungannya. Sedangkan untuk kelompok C, walaupun memiliki tanggungan, akan tetapi mereka memiliki partner, sehingga untuk charges dapat ditanggung bersama.
# * --> jumlah total charges terbesar, terdapat pada kelompok D dan A, yang mana kelommpok A tidak memiliki pasangan dan juga tanggungan, sedangkan untuk kelompok D yang memiliki jumlah total charges terbesar, mereka tidak memiliki tanggungan akan tetapi memiliki partner. Kelompok D dapat menjadi fakta bahwa memiliki partner tidak mengurangi jumlah total charges.
# * --> dapat dilihat juga dari jumlah customer pada masing-masing kelompok, untuk kelompok A terbanyak dikarenakan tidak memiliki partner dan tanggungan, untuk kelompok C dan D selisih <100, sedangkan untuk kelompok B dengan jumlah cutomer paling rendah.
